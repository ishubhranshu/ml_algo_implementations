# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../../data/indian_liver_patient.csv")
df.sample(3)
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 403   65    Male              0.7               0.2                   199
# 522   46  Female              0.8               0.2                   185
# 192   60    Male              2.3               0.6                   272
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 403                        19                          22             6.3
# 522                        24                          15             7.9
# 192                        79                          51             6.6
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# 403      3.6                         1.3        2
# 522      3.7                         0.8        1
# 192      3.5                         1.1        1

# %%
df = df.dropna()
df
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female              0.7               0.1                   187
# 1     62    Male             10.9               5.5                   699
# 2     62    Male              7.3               4.1                   490
# 3     58    Male              1.0               0.4                   182
# 4     72    Male              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 578   60    Male              0.5               0.1                   500
# 579   40    Male              0.6               0.1                    98
# 580   52    Male              0.8               0.2                   245
# 581   31    Male              1.3               0.5                   184
# 582   38    Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                          16                          18             6.8
# 1                          64                         100             7.5
# 2                          60                          68             7.0
# 3                          14                          20             6.8
# 4                          27                          59             7.3
# ..                        ...                         ...             ...
# 578                        20                          34             5.9
# 579                        35                          31             6.0
# 580                        48                          49             6.4
# 581                        29                          32             6.8
# 582                        21                          24             7.3
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0        3.3                        0.90        1
# 1        3.2                        0.74        1
# 2        3.3                        0.89        1
# 3        3.4                        1.00        1
# 4        2.4                        0.40        1
# ..       ...                         ...      ...
# 578      1.6                        0.37        2
# 579      3.2                        1.10        1
# 580      3.2                        1.00        1
# 581      3.4                        1.00        1
# 582      4.4                        1.50        2
#
# [579 rows x 11 columns]

# %%
from sklearn.preprocessing import LabelEncoder


for col in df.columns:
    if df[col].dtype == 'O':
        encoder = LabelEncoder()
        df[col]=encoder.fit_transform(df[col])
    
df.sample(3)
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 445   17       1              0.9               0.2                   279
# 7     29       0              0.9               0.3                   202
# 495   32       1              0.7               0.2                   165
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 445                        40                          46             7.3
# 7                          14                          11             6.7
# 495                        31                          29             6.1
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# 445      4.0                        1.20        2
# 7        3.6                        1.10        1
# 495      3.0                        0.96        2

# %%
x = df.iloc[:, :-1]
y = df.iloc[:, -1]

print(x.shape)
print(y.shape)
# Out:
# (579, 10)
# (579,)

# %%
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

print(xtrain.shape)
print(ytrain.shape)
print(xtest.shape)
print(ytest.shape)
# Out:
# (463, 10)
# (463,)
# (116, 10)
# (116,)

# %%
from sklearn.ensemble import AdaBoostClassifier

abc = AdaBoostClassifier()

abc.fit(xtrain, ytrain)
# Out:
# c:\Users\ishub\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# AdaBoostClassifier()

# %%
ypred = abc.predict(xtest)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(ytest, ypred)
# Out:
# 0.6551724137931034

# %%
grid = {'n_estimators': [500, 1000, 1500, 2000],
        'learning_rate': [0.0001, 0.001, 0.01, 1.0],
        'algorithm': ['SAMME', 'SAMME.R']
        }

# %%
from sklearn.model_selection import GridSearchCV

gsv = GridSearchCV(estimator=AdaBoostClassifier(), param_grid=grid, n_jobs=-1, cv=10, scoring='accuracy')

gsv.fit(x, y)
# Out:
# c:\Users\ishub\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# GridSearchCV(cv=10, estimator=AdaBoostClassifier(), n_jobs=-1,
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'learning_rate': [0.0001, 0.001, 0.01, 1.0],
#                          'n_estimators': [500, 1000, 1500, 2000]},
#              scoring='accuracy')

# %%
gsv.best_score_
# Out:
# 0.7305807622504537
